# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }
# document.title="AiiDAlab ChemShell Batch"

# %%
# %%capture
from aiida import load_profile

load_profile();

# %%
from aiidalab_chemshell.main import BatchApp

app = BatchApp()
