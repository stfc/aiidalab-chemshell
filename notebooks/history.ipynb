# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(line) {
#     return false;
# }
# document.title = "AiiDAlab ChemShell"

# %%
# %%capture
from aiida import load_profile
load_profile();

# %%
from aiidalab_chemshell.history import HistoryApp
app = HistoryApp()
