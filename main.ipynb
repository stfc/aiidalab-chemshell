# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }
# document.title="AiiDAlab ChemShell"

# %%
# %%capture
from aiida import load_profile 
load_profile();

# %%
from aiidalab_chemshell.main import MainApp
# pk = query["pk"][0] if "pk" in query else None 
app = MainApp()
